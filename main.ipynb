# %% [markdown]
# # Student Learning Preferences

# %% [markdown]
# ## Survey Design
#
# Features: 4 <br/>
# Levels: 3 <br/>
# Type: Nominal <br/>
#
# | Feature | Level 1 | Level 2 | Level 3 |
# |---|---|---|---|
# | Mode of learning | in-person | hybrid | online |
# | Learning resources provided | lecture notes | none | recorded lecture |
# | Tuition Cost | 57000 | 3900 | 28000 |
# | Academic Support  | flexible | fixed | none |
#
#
# ![Scenarios](./Scenerios.png)

# %%
import numpy as np
import pandas as pd

# %%
# block sample do not push to git
block1_A = pd.read_excel("./block 1 a.xlsx")
block1_A.columns
# Out:
# c:\Python310\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Index(['StartDate', 'EndDate', 'Status', 'IPAddress', 'Progress',
#        'Duration (in seconds)', 'Finished', 'RecordedDate', 'ResponseId',
#        'RecipientLastName', 'RecipientFirstName', 'RecipientEmail',
#        'ExternalReference', 'LocationLatitude', 'LocationLongitude',
#        'DistributionChannel', 'UserLanguage', '1', '2 ', '3', '4', '5', '6',
#        '7', '8', 'Q1_1', 'Q2_1', 'Q3_1', 'Q4_1', 'Q5_1', 'Q6_1', 'Q7_1',
#        'Q8_1'],
#       dtype='object')

# %%
cols = [ '1', '2 ', '3', '4', '5', '6','7', '8', 'Q1_1', 'Q2_1', 'Q3_1', 'Q4_1', 'Q5_1', 'Q6_1', 'Q7_1','Q8_1']

# %%
block1_A[cols][1:].head()
# Out:
#         1      2                 3          4                            5  \
# 1    Male  Junior  15 - 30 minutes         No         With parent/guardian
# 2  Female  Senior  15 - 30 minutes  Part-time         With parent/guardian
# 3    Male  Junior  15 - 30 minutes         No  Off campus with roommate(s)
# 4    Male  Junior   0 - 15 minutes  Part-time             Off campus alone
# 5    Male  Senior      45 - 1 hour  Part-time             Off campus alone
#
#                             6                  7               8  \
# 1  Neither agree nor disagree     Somewhat agree  $10,001-50,000
# 2           Somewhat disagree     Strongly agree  $10,001-50,000
# 3              Strongly agree  Strongly Disagree        $0-1,000
# 4              Somewhat agree     Strongly agree        $0-1,000
# 5              Strongly agree     Somewhat agree  $10,001-50,000
#
#                                            Q1_1  \
# 1  In-Person\nLecture Notes\n$28,000 \nFlexible
# ...
